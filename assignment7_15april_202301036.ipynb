# %% [markdown]
# <a href="https://colab.research.google.com/github/mittalichugh/bigdata/blob/main/assignment7_15april_202301036.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x=np.array([1,2,3,4,5])
y=np.array([2,4,5,7,10])
z=np.array(x*y)
n=np.size(x)

#y=a+bx
y1=np.sum(y)
x1=np.array(x**(2))


a= ((y1)*np.sum(x1)- (np.sum(x) * np.sum(z)))/ ((n*np.sum(x1)- (np.sum(x))**2 ))
print(a)

b=(n*(np.sum(z))- (np.sum(x))*(np.sum(y)))/((n*np.sum(x1)- (np.sum(x))**2 ))
print(b)

n=np.size(x)

ypred=[]

for i in range(5):
    t= a+ b*x[i]
    ypred.append(t)

print("The equation of linear regression is: ",a,"+",b,"x")

plt.scatter(x, y, color='blue', label=' x Data Points')
plt.scatter(x,ypred, color='yellow',label='y Predicted Points')

plt.plot(x, a + b * x, color='red', label='Linear Regression Line')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.legend()

plt.grid(True)
plt.show()
# Out:
# -0.1
# 1.9
# The equation of linear regression is:  -0.1 + 1.9 x

# %%
 import numpy as np
 from sklearn.linear_model import LinearRegression


 x = np.array([5, 15, 25, 35, 45, 55]).reshape((-1, 1))
 # x array should be 2d
 y = np.array([5, 20, 14, 32, 22, 38])

 model = LinearRegression()

 model.fit(x, y)

 model = LinearRegression().fit(x, y)

 print(f"intercept: {model.intercept_}")

 print(f"slope: {model.coef_}")

 y_pred = model.predict(x)

 print(f"predicted response:\n{y_pred}")

 y_pred = model.intercept_ + (model.coef_ * x)

 print(f"predicted response:\n{y_pred}")
# Out:
# intercept: 5.633333333333329
# slope: [0.54]
# predicted response:
# [ 8.33333333 13.73333333 19.13333333 24.53333333 29.93333333 35.33333333]
# predicted response:
# [[ 8.33333333]
#  [13.73333333]
#  [19.13333333]
#  [24.53333333]
#  [29.93333333]
#  [35.33333333]]
